# %% [markdown]
# <a href="https://colab.research.google.com/github/3s3s/3s3s.org/blob/master/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# сначала перейти в безопасную директорию
# %cd /content

# теперь можно удалять
# !rm -rf Fooocus

# фиксим зависимости
# !pip uninstall -y cupy cupy-cuda* numpy pymatting
# !pip install numpy==1.26.4 pymatting==1.1.8 pygit2==1.15.1

# ставим Fooocus
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd Fooocus

# запуск
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# ERROR: Invalid requirement: 'cupy-cuda*': Expected end or semicolon (after name and no valid version specifier)
#     cupy-cuda*
#              ^
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pymatting
#     Found existing installation: PyMatting 1.1.15
#     Uninstalling PyMatting-1.1.15:
#       Successfully uninstalled PyMatting-1.1.15
# ...
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 15.94 MiB/s, done.
# Resolving deltas: 100% (3850/3850), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# ...
